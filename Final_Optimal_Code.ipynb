# %%
# !pip install torch transformers datasets peft accelerate trl bitsandbytes nltk rouge-score scikit-learn
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Collecting datasets
#   Downloading datasets-3.5.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (0.14.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.5.2)
# Collecting trl
#   Downloading trl-0.16.1-py3-none-any.whl.metadata (12 kB)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec (from torch)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from trl) (13.9.4)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->trl) (0.1.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 113.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 91.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 53.3 MB/s eta 0:00:00
# Downloading datasets-3.5.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 34.2 MB/s eta 0:00:00
# Downloading trl-0.16.1-py3-none-any.whl (336 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.4/336.4 kB 32.0 MB/s eta 0:00:00
# Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl (76.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 11.0 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.3 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 19.7 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 16.1 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 19.8 MB/s eta 0:00:00
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=db09573f448f0fe3102438993fb535587e59e8574de68623e80976d92e1abb01
#   Stored in directory: /root/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# Successfully built rouge-score
# Installing collected packages: xxhash, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, fsspec, dill, rouge-score, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, nvidia-cusolver-cu12, datasets, bitsandbytes, trl
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.12.0 which is incompatible.
# Successfully installed bitsandbytes-0.45.5 datasets-3.5.0 dill-0.3.8 fsspec-2024.12.0 multiprocess-0.70.16 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 rouge-score-0.1.2 trl-0.16.1 xxhash-3.5.0

# %%
import os
import re
import torch
import numpy as np
from datasets import load_dataset
from sklearn.model_selection import KFold
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from rouge_score import rouge_scorer
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    DataCollatorForSeq2Seq,
    BitsAndBytesConfig
)
from trl import SFTTrainer, SFTConfig
from peft import LoraConfig, get_peft_model
from huggingface_hub import login

# Login to Hugging Face
HF_TOKEN = "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"
login(HF_TOKEN)
os.environ["HUGGINGFACE_TOKEN"] = HF_TOKEN
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
torch.cuda.empty_cache()
torch.cuda.reset_peak_memory_stats()

print("CUDA Available:", torch.cuda.is_available())
print("GPU Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU found!")

# Load Model & Tokenizer
MODEL_NAME = "meta-llama/Llama-3.2-3B-Instruct"
QUANT_CONFIG = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
)

model = AutoModelForCausalLM.from_pretrained(MODEL_NAME, quantization_config=QUANT_CONFIG, trust_remote_code=True, device_map="auto")
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
tokenizer.pad_token = tokenizer.eos_token

# Resize model embeddings if new tokens were added
model.resize_token_embeddings(len(tokenizer))
model.config.pad_token_id = tokenizer.pad_token_id
model.config.eos_token_id = tokenizer.eos_token_id
model.config.bos_token_id = tokenizer.bos_token_id

# Apply LoRA
LORA_CONFIG = LoraConfig(
    r=16,
    lora_alpha=16,
    lora_dropout=0.1,
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"]
)
model = get_peft_model(model, LORA_CONFIG)

# Load Dataset
dataset_path = "/content/250.csv"
dataset = load_dataset("csv", data_files=dataset_path, encoding="utf-8")['train']

def format_text(example):
    #instruction = "Rewrite the following sentence in Simplified Technical English without changing its meaning: "
    instruction = example["prompt"].strip()
    standard = example["standard_english"].strip()
    ste = example["ste"].strip()
    return {
        "input_text": f"{instruction} {standard}",
        "output_text": ste
    }
#dataset = dataset.map(format_text, remove_columns=["standard_english", "ste"])
dataset = dataset.map(format_text, remove_columns=["prompt", "standard_english", "ste"])

def tokenize_and_format(example):
    max_len = 384  # Adjust as needed
    # Tokenize both input and output together
    # This ensures that padding is applied to the combined sequence
    # resulting in consistent input and output lengths within a batch
    tokenized_example = tokenizer(
        example["input_text"],
        example["output_text"], # Tokenize output along with input
        truncation=True,
        padding='max_length', # Use 'max_length' for consistent padding
        max_length=max_len,
        add_special_tokens=True
    )

    # Extract input_ids, attention_mask, and labels
    input_ids = tokenized_example["input_ids"]
    attention_mask = tokenized_example["attention_mask"]

    # Create labels with -100 for padding
    labels = tokenized_example["input_ids"].copy()
    labels = [label if label != tokenizer.pad_token_id else -100 for label in labels]

    return {
        "input_ids": input_ids,
        "attention_mask": attention_mask,
        "labels": labels
    }

# Tokenize Dataset
dataset = dataset.map(tokenize_and_format, remove_columns=["input_text", "output_text"])

# Metrics and Post-processing
kf = KFold(n_splits=5, shuffle=True, random_state=3407)
bleu_scores, rouge1_scores, rougeL_scores, validation_losses, training_losses = [], [], [], [], []

def post_process_output(output, inputInstruct):
    if output and not output.endswith('.'):
        output = f"{output}."
    output = re.sub(f"^{re.escape(inputInstruct)}", "", output, count=1).strip()
    sentences = re.findall(r"[^.]*\.\"?(?=\s|$)", output)
    if sentences and len(sentences[0].strip()) <= 4 and len(sentences) > 1:
        return sentences[1].strip()
    return sentences[0].strip() if sentences else inputInstruct

def compute_metrics(predictions, references):
    bleu = sentence_bleu([references], predictions, smoothing_function=SmoothingFunction().method1)
    rouge = rouge_scorer.RougeScorer(['rouge1', 'rougeL'], use_stemmer=True).score(" ".join(references), " ".join(predictions))
    return {"bleu": bleu, "rouge1": rouge['rouge1'].fmeasure, "rougeL": rouge['rougeL'].fmeasure}

# Training Loop
for fold, (train_idx, val_idx) in enumerate(kf.split(dataset)):
    print(f"Training Fold {fold + 1}")
    train_data, val_data = dataset.select(train_idx), dataset.select(val_idx)

    trainer = SFTTrainer(
        model=model,
        train_dataset=train_data,
        eval_dataset=val_data,
        data_collator=DataCollatorForSeq2Seq(tokenizer=tokenizer, padding=True),
        args=SFTConfig(
            output_dir=f"./results_fold_{fold + 1}",
            eval_strategy="steps",
            eval_steps=50,
            label_names=["labels"],
            logging_steps=50,
            learning_rate=2e-5,
            warmup_steps=50,  # or use warmup_ratio=0.1
            lr_scheduler_type="cosine",  # or "linear"
            per_device_train_batch_size=1,
            per_device_eval_batch_size=1,
            gradient_accumulation_steps=8,
            num_train_epochs=5,
            weight_decay=0.05,
            save_total_limit=2,
            save_steps=1000,
            logging_dir=f'./logs_fold_{fold + 1}',
            fp16=True,
            dataset_text_field="input_ids",
            max_seq_length=512,
            dataset_num_proc=2,
            packing=False,
            load_best_model_at_end=True,
            metric_for_best_model="eval_loss",
            greater_is_better=False
        )
    )
    train_result = trainer.train()
    eval_results = trainer.evaluate()
    print("Evaluation Results:", eval_results)
    training_losses.append(train_result.training_loss)
    validation_losses.append(eval_results.get("eval_loss", 0))

    predictions, references = [], []
    for example in val_data:
        input_sentence = tokenizer.decode(
            [tok for tok, mask in zip(example["input_ids"], example["attention_mask"]) if mask == 1],
            skip_special_tokens=True
        )
        ground_truth = tokenizer.decode([t for t in example["labels"] if t != -100], skip_special_tokens=True)

        inputs = tokenizer(input_sentence, return_tensors="pt", truncation=True, padding=True, max_length=80)
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        input_ids = inputs["input_ids"].to(device)
        attention_mask = inputs["attention_mask"].to(device)

        with torch.no_grad():
            output = model.generate(
                input_ids=input_ids,
                attention_mask=attention_mask,
                max_length=100,
                do_sample=False,
                temperature=None,
                pad_token_id=tokenizer.pad_token_id,
                eos_token_id=tokenizer.eos_token_id,
                num_return_sequences=1,
                early_stopping=True
            )

        decoded_output = tokenizer.decode(output[0], skip_special_tokens=True)
        print(f"Input: {input_sentence}")
        #print(f"Output: {decoded_output}")
        print(f"Post Process Output: {post_process_output(decoded_output, input_sentence)}")
        print(f"Ground Truth: {ground_truth}")

        predictions.append(post_process_output(decoded_output, input_sentence))
        references.append(ground_truth)

    metrics = compute_metrics(predictions, references)
    bleu_scores.append(metrics["bleu"])
    rouge1_scores.append(metrics["rouge1"])
    rougeL_scores.append(metrics["rougeL"])
    print(f"Fold {fold + 1} - BLEU: {metrics['bleu']}, ROUGE-1: {metrics['rouge1']}, ROUGE-L: {metrics['rougeL']}")

# Final Evaluation Summary
print(f"Avg BLEU: {np.mean(bleu_scores)}, Std: {np.std(bleu_scores)}")
print(f"Avg ROUGE-1: {np.mean(rouge1_scores)}, Std: {np.std(rouge1_scores)}")
print(f"Avg ROUGE-L: {np.mean(rougeL_scores)}, Std: {np.std(rougeL_scores)}")
print(f"Avg Validation Loss: {np.mean(validation_losses)}, Std: {np.std(validation_losses)}")
print(f"Avg Training Loss: {np.mean(training_losses)}, Std: {np.std(training_losses)}")

# Save Final Model
#trainer.save_model("/content/drive/MyDrive/Models/250")
print("Training complete.")
# Out:
# CUDA Available: True
# GPU Name: Tesla T4
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Training Fold 1
#     <div>
#
#       <progress value='120' max='120' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [120/120 08:04, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>4.166500</td>
#       <td>3.018062</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>2.044300</td>
#       <td>1.865759</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='50' max='50' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [50/50 00:11]
#     </div>
# Evaluation Results: {'eval_loss': 1.8415019512176514, 'eval_runtime': 11.3313, 'eval_samples_per_second': 4.413, 'eval_steps_per_second': 4.413}
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:636: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:679: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# Input: Identify and replace non-STE words with approved alternatives turn the control to the absolutely closed position.turn the control to the fully closed position.
# Post Process Output: Question: What is the correct way to turn the control to the closed position?Question: What is the correct.
# Ground Truth: Identify and replace non-STE words with approved alternatives turn the control to the absolutely closed position.turn the control to the fully closed position.
# Input: Identify and replace non-STE words with approved alternatives contaminated oil must be replaced.replace the dirty oil.
# Post Process Output: Question: The oil must.
# Ground Truth: Identify and replace non-STE words with approved alternatives contaminated oil must be replaced.replace the dirty oil.
# Input: Identify and replace non-STE words with approved alternatives replace all components that are worn beyond their maximum limits.replace all components that are worn more than the maximum limits.
# Post Process Output: The following are approved alternatives.
# Ground Truth: Identify and replace non-STE words with approved alternatives replace all components that are worn beyond their maximum limits.replace all components that are worn more than the maximum limits.
# Input: Identify and replace non-STE words with approved alternatives fit the wheel.install the wheel.
# Post Process Output: The wheel is installed.
# Ground Truth: Identify and replace non-STE words with approved alternatives fit the wheel.install the wheel.
# Input: Identify and replace non-STE words with approved alternatives remove the unnecessary ground equipment.remove the ground equipment that is not necessary.
# Post Process Output: Question: What is the purpose of the ground equipment?A) To provide a safe working surface for the vehicle.
# Ground Truth: Identify and replace non-STE words with approved alternatives remove the unnecessary ground equipment.remove the ground equipment that is not necessary.
# Input: Identify and replace non-STE words with approved alternatives the bottom edge of the panel is covered with carpet.the bottom edge of the panel has carpet on it.
# Post Process Output: The bottom edge of the panel.
# Ground Truth: Identify and replace non-STE words with approved alternatives the bottom edge of the panel is covered with carpet.the bottom edge of the panel has carpet on it.
# Input: Identify and replace non-STE words with approved alternatives replace the cap if its condition is not acceptable.replace the cap if its condition is not satisfactory.
# Post Process Output: The cap must be replaced if its condition is not.
# Ground Truth: Identify and replace non-STE words with approved alternatives replace the cap if its condition is not acceptable.replace the cap if its condition is not satisfactory.
# Input: Identify and replace non-STE words with approved alternatives check the damage.look for damage.
# Post Process Output: Question: The damage is apparent.
# Ground Truth: Identify and replace non-STE words with approved alternatives check the damage.look for damage.
# Input: Identify and replace non-STE words with approved alternatives secure the clamp block across the control lever forks with safety wire.safety the clamp block across the control lever forks with safety wire.
# Post Process Output: Question.
# Ground Truth: Identify and replace non-STE words with approved alternatives secure the clamp block across the control lever forks with safety wire.safety the clamp block across the control lever forks with safety wire.
# Input: Identify and replace non-STE words with approved alternatives grip the front of the bicycle.hold the front of the bicycle.
# Post Process Output: The.
# Ground Truth: Identify and replace non-STE words with approved alternatives grip the front of the bicycle.hold the front of the bicycle.
# Input: Identify and replace non-STE words with approved alternatives the turbine combusts fuel.the turbine burns fuel.
# Post Process Output: The turbine burns fuel.
# Ground Truth: Identify and replace non-STE words with approved alternatives the turbine combusts fuel.the turbine burns fuel.
# Input: Identify and replace non-STE words with approved alternatives do not handle the printed circuit card.do not touch the printed circuit card.
# Post Process Output: Question: What is the correct way to handle the printed.
# Ground Truth: Identify and replace non-STE words with approved alternatives do not handle the printed circuit card.do not touch the printed circuit card.
# Input: Identify and replace non-STE words with approved alternatives the diameter of the tube is too little.the diameter of the tube is too small.
# Post Process Output: The diameter of the tube is too small.
# Ground Truth: Identify and replace non-STE words with approved alternatives the diameter of the tube is too little.the diameter of the tube is too small.
# Input: Identify and replace non-STE words with approved alternatives the usage of incorrect thinners can cause problems.do not use incorrect thinners. this can cause problems.
# Post Process Output: Question: The use of incorrect thinners can.
# Ground Truth: Identify and replace non-STE words with approved alternatives the usage of incorrect thinners can cause problems.do not use incorrect thinners. this can cause problems.
# Input: Identify and replace non-STE words with approved alternatives if you decide not to replace the existing unit, watch its temperature for at least 15 cycles.if your decision is not to replace the unit, monitor its temperature for a minimum of 15 cycles.
# Post Process Output: The temperature of the unit will be monitored for a minimum of 15 cycles if you do not replace it.
# Ground Truth: Identify and replace non-STE words with approved alternatives if you decide not to replace the existing unit, watch its temperature for at least 15 cycles.if your decision is not to replace the unit, monitor its temperature for a minimum of 15 cycles.
# Input: Identify and replace non-STE words with approved alternatives fit the light bulb to the front and back lights.install the light bulb to the front and rear lights.
# Post Process Output: The approved alternatives are:The approved alternatives are: fit the light bulb to the front and back lights.
# Ground Truth: Identify and replace non-STE words with approved alternatives fit the light bulb to the front and back lights.install the light bulb to the front and rear lights.
# Input: Identify and replace non-STE words with approved alternatives confirm the door is flush with the fuselage skin.make sure that the door is flush with the fuselage skin.
# Post Process Output: The door must be flush with the.
# Ground Truth: Identify and replace non-STE words with approved alternatives confirm the door is flush with the fuselage skin.make sure that the door is flush with the fuselage skin.
# Input: Identify and replace non-STE words with approved alternatives build the unit.assemble the unit
# Post Process Output: Question: The approved alternatives are listed.
# Ground Truth: Identify and replace non-STE words with approved alternatives build the unit.assemble the unit
# Input: Identify and replace non-STE words with approved alternatives apply sufficient heat to the unit in the process of doing this repair.during this repair, apply sufficient heat to the unit.
# Post Process Output: Question:Identify and replace non-STE words with approved alternatives apply sufficient heat to.
# Ground Truth: Identify and replace non-STE words with approved alternatives apply sufficient heat to the unit in the process of doing this repair.during this repair, apply sufficient heat to the unit.
# Input: Identify and replace non-STE words with approved alternatives ensure that the adhesion between the honeycomb core and the skin is exact.make sure that the bond between the honeycomb core and the skin is correct.
# Post Process Output: The skin should be free of any debris.
# Ground Truth: Identify and replace non-STE words with approved alternatives ensure that the adhesion between the honeycomb core and the skin is exact.make sure that the bond between the honeycomb core and the skin is correct.
# Input: Identify and replace non-STE words with approved alternatives by means of the hand pump, pressurize the system to 150 bar.pressurize the system to 150 bar with the hand pump.
# Post Process Output: The hand pump is used to.
# Ground Truth: Identify and replace non-STE words with approved alternatives by means of the hand pump, pressurize the system to 150 bar.pressurize the system to 150 bar with the hand pump.
# Input: Identify and replace non-STE words with approved alternatives it can harm your eyes.it can cause injury to your eyes.
# Post Process Output: The approved alternative is.
# Ground Truth: Identify and replace non-STE words with approved alternatives it can harm your eyes.it can cause injury to your eyes.
# Input: Identify and replace non-STE words with approved alternatives after you put out the fire, close the valve on the fire extinguisher.after you extinguish the fire, close the valve on the fire extinguisher.
# Post Process Output: The valve should be closed.
# Ground Truth: Identify and replace non-STE words with approved alternatives after you put out the fire, close the valve on the fire extinguisher.after you extinguish the fire, close the valve on the fire extinguisher.
# Input: Identify and replace non-STE words with approved alternatives fix the length of the control rod as required.set the length of the control rod as necessary.
# Post Process Output: Question: The approved.
# Ground Truth: Identify and replace non-STE words with approved alternatives fix the length of the control rod as required.set the length of the control rod as necessary.
# Input: Identify and replace non-STE words with approved alternatives the type typically used on most bicycles is the cantilever.the one found on most bicycles is the cantilever.
# Post Process Output: Question: What is the type of brake used on most.
# Ground Truth: Identify and replace non-STE words with approved alternatives the type typically used on most bicycles is the cantilever.the one found on most bicycles is the cantilever.
# Input: Identify and replace non-STE words with approved alternatives remove all fouled filter elements.remove all clogged filter elements.
# Post Process Output: The filter.
# Ground Truth: Identify and replace non-STE words with approved alternatives remove all fouled filter elements.remove all clogged filter elements.
# Input: Identify and replace non-STE words with approved alternatives ensure that deflection is 23 deg.make sure that the position is 23 deg.
# Post Process Output: Question: The position should be 23 degrees.
# Ground Truth: Identify and replace non-STE words with approved alternatives ensure that deflection is 23 deg.make sure that the position is 23 deg.
# Input: Identify and replace non-STE words with approved alternatives broadcast the data on both channels.rub the surface quickly with a soft, dry cloth.
# Post Process Output: The surface should be clean and free of moisture.
# Ground Truth: Identify and replace non-STE words with approved alternatives broadcast the data on both channels.rub the surface quickly with a soft, dry cloth.
# Input: Identify and replace non-STE words with approved alternatives ensure that the pads are correctly mounted in the center of the inner diameter of the brake surface.make sure that the pads are correctly installed in the center of the inner diameter of the brake surface.
# Post Process Output: The brake pads must be installed in the center of the.
# Ground Truth: Identify and replace non-STE words with approved alternatives ensure that the pads are correctly mounted in the center of the inner diameter of the brake surface.make sure that the pads are correctly installed in the center of the inner diameter of the brake surface.
# Input: Identify and replace non-STE words with approved alternatives if you do not follow this instruction, damage may happen.if you do not obey this instruction, damage can occur.
# Post Process Output: B) To.
# Ground Truth: Identify and replace non-STE words with approved alternatives if you do not follow this instruction, damage may happen.if you do not obey this instruction, damage can occur.
# Input: Identify and replace non-STE words with approved alternatives the cap is separate from the coupling.the cap is not attached to the coupling.
# Post Process Output: The cap.
# Ground Truth: Identify and replace non-STE words with approved alternatives the cap is separate from the coupling.the cap is not attached to the coupling.
# Input: Identify and replace non-STE words with approved alternatives turn the rotating tube 75 degrees.turn the rotating tube 75 degrees.
# Post Process Output: The arrow on the tube shows the direction of rotation.
# Ground Truth: Identify and replace non-STE words with approved alternatives turn the rotating tube 75 degrees.turn the rotating tube 75 degrees.
# Input: Identify and replace non-STE words with approved alternatives ride the bicycle ahead.ride forward the bicycle.
# Post Process Output: Question: What is the approved alternative to the non-STE word "ride the bicycle.
# Ground Truth: Identify and replace non-STE words with approved alternatives ride the bicycle ahead.ride forward the bicycle.
# Input: Identify and replace non-STE words with approved alternatives if you have the option, do the inspection in daylight.if possible, do the inspection in daylight.
# Post Process Output: The approved alternatives are: do the inspection in daylight.
# Ground Truth: Identify and replace non-STE words with approved alternatives if you have the option, do the inspection in daylight.if possible, do the inspection in daylight.
# Input: Identify and replace non-STE words with approved alternatives microswitches are activated by levers.the levers operate the microswitches.
# Post Process Output: The levers operate the microswitch.
# Ground Truth: Identify and replace non-STE words with approved alternatives microswitches are activated by levers.the levers operate the microswitches.
# Input: Identify and replace non-STE words with approved alternatives any request for assistance should be addressed to the manufacturer.if aid is necessary, write to the manufacturer.
# Post Process Output: Question: What is the purpose of the manufacturer's instructions?A) To provide information about the product.
# Ground Truth: Identify and replace non-STE words with approved alternatives any request for assistance should be addressed to the manufacturer.if aid is necessary, write to the manufacturer.
# Input: Identify and replace non-STE words with approved alternatives cut the bracket to create a clearance.cut the bracket to make a clearance.
# Post Process Output: Question: The bracket should be.
# Ground Truth: Identify and replace non-STE words with approved alternatives cut the bracket to create a clearance.cut the bracket to make a clearance.
# Input: Identify and replace non-STE words with approved alternatives unplug the power supply.disconnect the power supply.
# Post Process Output: Question:Identify and replace non-STE words with approved alternatives.
# Ground Truth: Identify and replace non-STE words with approved alternatives unplug the power supply.disconnect the power supply.
# Input: Identify and replace non-STE words with approved alternatives if you have any questions about this document, send an e-mail to the address that follows:if you have questions about this document, send an e-mail to the address that follows:
# Post Process Output: The following is a list of the items that you need to have on board:The following is a list of the items that you need to have on board:The following is a list of the items that you need to have on board:.
# Ground Truth: Identify and replace non-STE words with approved alternatives if you have any questions about this document, send an e-mail to the address that follows:if you have questions about this document, send an e-mail to the address that follows:
# Input: Identify and replace non-STE words with approved alternatives this procedure entails the use of special tools.for this procedure, you must use special tools.
# Post Process Output: The.
# Ground Truth: Identify and replace non-STE words with approved alternatives this procedure entails the use of special tools.for this procedure, you must use special tools.
# Input: Identify and replace non-STE words with approved alternatives do not strike the cartridge.do not hit the cartridge.
# Post Process Output: The cartridge is not hit.
# Ground Truth: Identify and replace non-STE words with approved alternatives do not strike the cartridge.do not hit the cartridge.
# Input: Identify and replace non-STE words with approved alternatives inspect the chain.do the checks on the chain.
# Post Process Output: Question: The approved alternatives.
# Ground Truth: Identify and replace non-STE words with approved alternatives inspect the chain.do the checks on the chain.
# Input: Identify and replace non-STE words with approved alternatives if the trim tab regulation is wrong, perform steps 7 thru 10.if the trim tab adjustment is incorrect, do steps 7 thru 10.
# Post Process Output: The.
# Ground Truth: Identify and replace non-STE words with approved alternatives if the trim tab regulation is wrong, perform steps 7 thru 10.if the trim tab adjustment is incorrect, do steps 7 thru 10.
# Input: Rewrite the following sentence in a Simplified Technical English format. centralize the controls.set the controls to the neutral position.
# Post Process Output: Question: The controls should.
# Ground Truth: Rewrite the following sentence in a Simplified Technical English format. centralize the controls.set the controls to the neutral position.
# Input: Rewrite the following sentence in a Simplified Technical English format. confirm that the surface is dry.make sure that the surface is dry.
# Post Process Output: The surface is dry.
# Ground Truth: Rewrite the following sentence in a Simplified Technical English format. confirm that the surface is dry.make sure that the surface is dry.
# Input: Rewrite the following sentence in a Simplified Technical English format. you can use the spoke nipples to manipulate the tension of the spokes.you can use the spoke nipples to adjust the tension of the spokes.
# Post Process Output: The spoke nipples can be used to adjust the tension of the.
# Ground Truth: Rewrite the following sentence in a Simplified Technical English format. you can use the spoke nipples to manipulate the tension of the spokes.you can use the spoke nipples to adjust the tension of the spokes.
# Input: Rewrite the following sentence in a Simplified Technical English format. whoever is in this area must use a respirator.all persons who are in this area must use a respirator.
# Post Process Output: The original sentence is in the Simplified Technical English format.
# Ground Truth: Rewrite the following sentence in a Simplified Technical English format. whoever is in this area must use a respirator.all persons who are in this area must use a respirator.
# Input: Rewrite the following sentence in a Simplified Technical English format. use another washer if necessary.add a washer if necessary.
# Post Process Output: ".
# Ground Truth: Rewrite the following sentence in a Simplified Technical English format. use another washer if necessary.add a washer if necessary.
# Input: Rewrite the following sentence in a Simplified Technical English format. the system is entirely automatic.the system is fully automatic.
# Post Process Output: The system is fully automatic.
# Ground Truth: Rewrite the following sentence in a Simplified Technical English format. the system is entirely automatic.the system is fully automatic.
# Input: Rewrite the following sentence in a Simplified Technical English format. the engine and all ancillary equipment use the same lubricant.the engine and all auxiliary equipment use the same lubricant.
# Post Process Output: The engine and all auxiliary equipment use the same.
# Ground Truth: Rewrite the following sentence in a Simplified Technical English format. the engine and all ancillary equipment use the same lubricant.the engine and all auxiliary equipment use the same lubricant.
# Fold 1 - BLEU: 0, ROUGE-1: 0.3919478981645944, ROUGE-L: 0.2912966252220249
# Training Fold 2
#     <div>
#
#       <progress value='120' max='120' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [120/120 08:06, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.688500</td>
#       <td>1.686556</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.499100</td>
#       <td>1.584984</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='50' max='50' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [50/50 00:11]
#     </div>
# Evaluation Results: {'eval_loss': 1.5810000896453857, 'eval_runtime': 11.3917, 'eval_samples_per_second': 4.389, 'eval_steps_per_second': 4.389}
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:636: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:679: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# Input: Identify and replace non-STE words with approved alternatives wipe excess compound from the gasket.remove unwanted compound from the gasket.
# Post Process Output: The approved alternatives.
# Ground Truth: Identify and replace non-STE words with approved alternatives wipe excess compound from the gasket.remove unwanted compound from the gasket.
# Input: Identify and replace non-STE words with approved alternatives deaerate the number 1 hydraulic system.bleed the number 1 hydraulic system.
# Post Process Output: The number.
# Ground Truth: Identify and replace non-STE words with approved alternatives deaerate the number 1 hydraulic system.bleed the number 1 hydraulic system.
# Input: Identify and replace non-STE words with approved alternatives due to the small diameter of the hole, the flow is low.because of the small diameter of the hole, the flow is low.
# Post Process Output: The flow is low because of the small hole.
# Ground Truth: Identify and replace non-STE words with approved alternatives due to the small diameter of the hole, the flow is low.because of the small diameter of the hole, the flow is low.
# Input: Identify and replace non-STE words with approved alternatives slip the carriage along the flap track.move the carriage along the flap track.
# Post Process Output: The approved.
# Ground Truth: Identify and replace non-STE words with approved alternatives slip the carriage along the flap track.move the carriage along the flap track.
# Input: Identify and replace non-STE words with approved alternatives bars deflect to the right.the bars move to the right side.
# Post Process Output: The.
# Ground Truth: Identify and replace non-STE words with approved alternatives bars deflect to the right.the bars move to the right side.
# Input: Identify and replace non-STE words with approved alternatives check that valves do not bind.make sure that the valves move freely.
# Post Process Output: The valves must not be blocked.
# Ground Truth: Identify and replace non-STE words with approved alternatives check that valves do not bind.make sure that the valves move freely.
# Input: Identify and replace non-STE words with approved alternatives center the piston in the sleeve.align the piston with the center of the sleeve.
# Post Process Output: The piston must be aligned with the center of.
# Ground Truth: Identify and replace non-STE words with approved alternatives center the piston in the sleeve.align the piston with the center of the sleeve.
# Input: Identify and replace non-STE words with approved alternatives if rough spots are encountered, remove them with emery cloth.if you find rough areas, remove them with emery cloth.
# Post Process Output: The following are examples of non-.
# Ground Truth: Identify and replace non-STE words with approved alternatives if rough spots are encountered, remove them with emery cloth.if you find rough areas, remove them with emery cloth.
# Input: Identify and replace non-STE words with approved alternatives the gyro requires precise adjustment.the gyro adjustment must be accurate.
# Post Process Output: The gyro.
# Ground Truth: Identify and replace non-STE words with approved alternatives the gyro requires precise adjustment.the gyro adjustment must be accurate.
# Input: Identify and replace non-STE words with approved alternatives hold the flange in its position. next, install the bolt.hold the flange in its position. then, install the bolt.
# Post Process Output: The approved alternative is.
# Ground Truth: Identify and replace non-STE words with approved alternatives hold the flange in its position. next, install the bolt.hold the flange in its position. then, install the bolt.
# Input: Identify and replace non-STE words with approved alternatives allocate the different maintenance tasks to technicians.give the different maintenance tasks to the technicians.
# Post Process Output: The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are.
# Ground Truth: Identify and replace non-STE words with approved alternatives allocate the different maintenance tasks to technicians.give the different maintenance tasks to the technicians.
# Input: Identify and replace non-STE words with approved alternatives take out the bottom bolt.remove the bottom bolt.
# Post Process Output: The.
# Ground Truth: Identify and replace non-STE words with approved alternatives take out the bottom bolt.remove the bottom bolt.
# Input: Identify and replace non-STE words with approved alternatives suspend the engine in a fireproof bay.hang the engine in a fireproof bay.
# Post Process Output: The fireproof.
# Ground Truth: Identify and replace non-STE words with approved alternatives suspend the engine in a fireproof bay.hang the engine in a fireproof bay.
# Input: Identify and replace non-STE words with approved alternatives haul the hydraulic cart away from the aircraft before you start the engine.move the hydraulic cart away from the aircraft before you start the engine.
# Post Process Output: The approved alternatives are: move the hydraulic cart away from the aircraft before you start the engine.
# Ground Truth: Identify and replace non-STE words with approved alternatives haul the hydraulic cart away from the aircraft before you start the engine.move the hydraulic cart away from the aircraft before you start the engine.
# Input: Identify and replace non-STE words with approved alternatives equivalent materials are also permissible.equivalent materials are also permitted.
# Post Process Output: The following alternatives are allowed.
# Ground Truth: Identify and replace non-STE words with approved alternatives equivalent materials are also permissible.equivalent materials are also permitted.
# Input: Identify and replace non-STE words with approved alternatives if you are not certain that the results are correct, do the test again.if you are not sure that the results are correct, do the test again.
# Post Process Output: The following.
# Ground Truth: Identify and replace non-STE words with approved alternatives if you are not certain that the results are correct, do the test again.if you are not sure that the results are correct, do the test again.
# Input: Identify and replace non-STE words with approved alternatives warm the mixture before use.make the mixture warm before you use it.
# Post Process Output: The.
# Ground Truth: Identify and replace non-STE words with approved alternatives warm the mixture before use.make the mixture warm before you use it.
# Input: Identify and replace non-STE words with approved alternatives the seat is to be installed before you install the cushion.before you install the cushion, install the seat.
# Post Process Output: The seat must be installed before.
# Ground Truth: Identify and replace non-STE words with approved alternatives the seat is to be installed before you install the cushion.before you install the cushion, install the seat.
# Input: Identify and replace non-STE words with approved alternatives insert the fork.push in the fork.
# Post Process Output: The fork is put into the fork.
# Ground Truth: Identify and replace non-STE words with approved alternatives insert the fork.push in the fork.
# Input: Identify and replace non-STE words with approved alternatives shifters are mechanisms for changing gears on the bicycle.the shifters are the mechanisms that you use to change the gears on the bicycle.
# Post Process Output: The shifters are the mechanisms.
# Ground Truth: Identify and replace non-STE words with approved alternatives shifters are mechanisms for changing gears on the bicycle.the shifters are the mechanisms that you use to change the gears on the bicycle.
# Input: Identify and replace non-STE words with approved alternatives exhaust all the hydraulic pressure in the accumulator.release the hydraulic pressure in the accumulator.
# Post Process Output: The pressure will be zero.
# Ground Truth: Identify and replace non-STE words with approved alternatives exhaust all the hydraulic pressure in the accumulator.release the hydraulic pressure in the accumulator.
# Input: Identify and replace non-STE words with approved alternatives if the circuit breaker pops, de-energize the circuit.if the circuit breaker opens, de-energize the circuit.
# Post Process Output: The circuit breaker trips.
# Ground Truth: Identify and replace non-STE words with approved alternatives if the circuit breaker pops, de-energize the circuit.if the circuit breaker opens, de-energize the circuit.
# Input: Identify and replace non-STE words with approved alternatives a fuel pump is mounted in zone 10.a fuel pump is installed in zone 10.
# Post Process Output: The fuel.
# Ground Truth: Identify and replace non-STE words with approved alternatives a fuel pump is mounted in zone 10.a fuel pump is installed in zone 10.
# Input: Identify and replace non-STE words with approved alternatives neither of the units must operate.the two units must not operate.
# Post Process Output: The two.
# Ground Truth: Identify and replace non-STE words with approved alternatives neither of the units must operate.the two units must not operate.
# Input: Identify and replace non-STE words with approved alternatives without this modification, the service life of the unit can be uncertain.without this modification, it is possible that the service life of this unit will be shorter than usual.
# Post Process Output: The modification must.
# Ground Truth: Identify and replace non-STE words with approved alternatives without this modification, the service life of the unit can be uncertain.without this modification, it is possible that the service life of this unit will be shorter than usual.
# Input: Identify and replace non-STE words with approved alternatives mix the correct quantity of pigment proportional to the quantity of solvent.mix the pigment and solvent in the correct proportions.
# Post Process Output: The approved quantity of pigment is the.
# Ground Truth: Identify and replace non-STE words with approved alternatives mix the correct quantity of pigment proportional to the quantity of solvent.mix the pigment and solvent in the correct proportions.
# Input: Identify and replace non-STE words with approved alternatives split casings must be replaced.replace damaged casings.
# Post Process Output: The.
# Ground Truth: Identify and replace non-STE words with approved alternatives split casings must be replaced.replace damaged casings.
# Input: Identify and replace non-STE words with approved alternatives gently tap the flap surface.lightly tap the flap surface.
# Post Process Output: The approved alternatives are: Gently tap the flap.
# Ground Truth: Identify and replace non-STE words with approved alternatives gently tap the flap surface.lightly tap the flap surface.
# Input: Identify and replace non-STE words with approved alternatives the solvent is combustible.the solvent is flammable.
# Post Process Output: The solvent.
# Ground Truth: Identify and replace non-STE words with approved alternatives the solvent is combustible.the solvent is flammable.
# Input: Identify and replace non-STE words with approved alternatives there is a point of weakness in the strut.there is a weak point in the strut.
# Post Process Output: The strut is a.
# Ground Truth: Identify and replace non-STE words with approved alternatives there is a point of weakness in the strut.there is a weak point in the strut.
# Input: Identify and replace non-STE words with approved alternatives do an inspection every 20 000 flight hours.do an inspection at intervals of 20 000 flight hours.
# Post Process Output: The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are.
# Ground Truth: Identify and replace non-STE words with approved alternatives do an inspection every 20 000 flight hours.do an inspection at intervals of 20 000 flight hours.
# Input: Identify and replace non-STE words with approved alternatives recoil the probe wire back on the spool.wind the probe wire back on the spool.
# Post Process Output: The safety of.
# Ground Truth: Identify and replace non-STE words with approved alternatives recoil the probe wire back on the spool.wind the probe wire back on the spool.
# Input: Identify and replace non-STE words with approved alternatives if the adjustment is incomplete, the values shown on the indicator will be incorrect.if the adjustment is not completed, the values shown on the indicator will be incorrect.
# Post Process Output: The indicator will not give the correct.
# Ground Truth: Identify and replace non-STE words with approved alternatives if the adjustment is incomplete, the values shown on the indicator will be incorrect.if the adjustment is not completed, the values shown on the indicator will be incorrect.
# Input: Identify and replace non-STE words with approved alternatives put the repair sheet exactly on the damaged area.put the repair sheet accurately on the damaged area.
# Post Process Output: The repair sheet.
# Ground Truth: Identify and replace non-STE words with approved alternatives put the repair sheet exactly on the damaged area.put the repair sheet accurately on the damaged area.
# Input: Identify and replace non-STE words with approved alternatives strip the insulation from the wire.remove the insulation from the wire.
# Post Process Output: The insulation must be.
# Ground Truth: Identify and replace non-STE words with approved alternatives strip the insulation from the wire.remove the insulation from the wire.
# Input: Identify and replace non-STE words with approved alternatives since the fluid level is incorrect, the system will not function.because the fluid level is incorrect, the system will not operate.
# Post Process Output: The system will not operate if the fluid level.
# Ground Truth: Identify and replace non-STE words with approved alternatives since the fluid level is incorrect, the system will not function.because the fluid level is incorrect, the system will not operate.
# Input: Identify and replace non-STE words with approved alternatives apply the parking brake when the brakes have cooled.operate the parking brake when the brakes are cool.
# Post Process Output: The parking.
# Ground Truth: Identify and replace non-STE words with approved alternatives apply the parking brake when the brakes have cooled.operate the parking brake when the brakes are cool.
# Input: Identify and replace non-STE words with approved alternatives make sure that the end of the safety wire will not injure personnel.make sure that the end of the safety wire will not cause injury to personnel.
# Post Process Output: The safety wire must be cut to the correct.
# Ground Truth: Identify and replace non-STE words with approved alternatives make sure that the end of the safety wire will not injure personnel.make sure that the end of the safety wire will not cause injury to personnel.
# Input: Identify and replace non-STE words with approved alternatives arrest the flow for 10 seconds.stop the flow for 10 seconds.
# Post Process Output: The approved.
# Ground Truth: Identify and replace non-STE words with approved alternatives arrest the flow for 10 seconds.stop the flow for 10 seconds.
# Input: Identify and replace non-STE words with approved alternatives no leaks permitted.make sure that there are no leaks.
# Post Process Output: The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are:The approved alternatives are.
# Ground Truth: Identify and replace non-STE words with approved alternatives no leaks permitted.make sure that there are no leaks.
# Input: Identify and replace non-STE words with approved alternatives brake levers are also located on the handlebar.the brake levers are also on the handle bar.
# Post Process Output: The brake levers are on the handle bar.
# Ground Truth: Identify and replace non-STE words with approved alternatives brake levers are also located on the handlebar.the brake levers are also on the handle bar.
# Input: Identify and replace non-STE words with approved alternatives there must be no irregularities in the surface finish.there must be no defects in the surface finish.
# Post Process Output: The surface finish must be smooth.
# Ground Truth: Identify and replace non-STE words with approved alternatives there must be no irregularities in the surface finish.there must be no defects in the surface finish.
# Input: Identify and replace non-STE words with approved alternatives it is vital to set the indicator back to zero after the test.after the test, it is mandatory to set the indicator back to zero.
# Post Process Output: The test is a good way to.
# Ground Truth: Identify and replace non-STE words with approved alternatives it is vital to set the indicator back to zero after the test.after the test, it is mandatory to set the indicator back to zero.
# Input: Identify and replace non-STE words with approved alternatives allow the bicycle to dry.let the bicycle dry.
# Post Process Output: The bicycle.
# Ground Truth: Identify and replace non-STE words with approved alternatives allow the bicycle to dry.let the bicycle dry.
# Input: Identify and replace non-STE words with approved alternatives the ship certificate should meet all the authories' requirements.the ship certificate must comply with all the requirements of the authorities.
# Post Process Output: The ship certificate must meet all the requirements of.
# Ground Truth: Identify and replace non-STE words with approved alternatives the ship certificate should meet all the authories' requirements.the ship certificate must comply with all the requirements of the authorities.
# Input: Identify and replace non-STE words with approved alternatives when you stop the power supply, the temperature will decrease soon.when you stop the power supply, the temperature will decrease in approximately 1 minute.
# Post Process Output: The temperature will decrease.
# Ground Truth: Identify and replace non-STE words with approved alternatives when you stop the power supply, the temperature will decrease soon.when you stop the power supply, the temperature will decrease in approximately 1 minute.
# Input: Rewrite the following sentence in a Simplified Technical English format. ensure that the glued area is larger than the patch.make sure that the area with the glue is larger than the patch.
# Post Process Output: The patch is applied to.
# Ground Truth: Rewrite the following sentence in a Simplified Technical English format. ensure that the glued area is larger than the patch.make sure that the area with the glue is larger than the patch.
# Input: Rewrite the following sentence in a Simplified Technical English format. if the speech is not audible, replace the unit.if you cannot hear the voice, replace the unit.
# Post Process Output: The unit must be replaced if you cannot hear the voice.
# Ground Truth: Rewrite the following sentence in a Simplified Technical English format. if the speech is not audible, replace the unit.if you cannot hear the voice, replace the unit.
# Input: Rewrite the following sentence in a Simplified Technical English format. make sure that the green light on the panel extinguishes.make sure that the green light on the panel is off.
# Post Process Output: The green.
# Ground Truth: Rewrite the following sentence in a Simplified Technical English format. make sure that the green light on the panel extinguishes.make sure that the green light on the panel is off.
# Input: Rewrite the following sentence in a Simplified Technical English format. dampen the cloth with solvent.make the cloth moist with solvent.
# Post Process Output: The original sentence is not clear.
# Ground Truth: Rewrite the following sentence in a Simplified Technical English format. dampen the cloth with solvent.make the cloth moist with solvent.
# Fold 2 - BLEU: 0, ROUGE-1: 0.3952095808383234, ROUGE-L: 0.26467065868263473
# Training Fold 3
#     <div>
#
#       <progress value='120' max='120' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [120/120 08:06, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.383200</td>
#       <td>1.331044</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.145200</td>
#       <td>1.294104</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='50' max='50' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [50/50 00:11]
#     </div>
# Evaluation Results: {'eval_loss': 1.3011192083358765, 'eval_runtime': 11.4279, 'eval_samples_per_second': 4.375, 'eval_steps_per_second': 4.375}
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:636: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:679: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# Input: Identify and replace non-STE words with approved alternatives make sure that the valve is operable.make sure that the valve can operate.
# Post Process Output: The information in this section.
# Ground Truth: Identify and replace non-STE words with approved alternatives make sure that the valve is operable.make sure that the valve can operate.
# Input: Identify and replace non-STE words with approved alternatives the horizon bar may drift slightly.the horizon bar can move a small distance.
# Post Process Output: The horizon bar can move a.
# Ground Truth: Identify and replace non-STE words with approved alternatives the horizon bar may drift slightly.the horizon bar can move a small distance.
# Input: Identify and replace non-STE words with approved alternatives mask the first layer of tape across the cutout and the second and third layers diagonally.apply the first layer of tape across the cutout and the second and third layers diagonally.
# Post Process Output: The.
# Ground Truth: Identify and replace non-STE words with approved alternatives mask the first layer of tape across the cutout and the second and third layers diagonally.apply the first layer of tape across the cutout and the second and third layers diagonally.
# Input: Identify and replace non-STE words with approved alternatives the removal procedure is common to both items.the removal procedure is the same for the two items.
# Post Process Output: The.
# Ground Truth: Identify and replace non-STE words with approved alternatives the removal procedure is common to both items.the removal procedure is the same for the two items.
# Input: Identify and replace non-STE words with approved alternatives wash the bike with water.clean the bicycle with water.
# Post Process Output: The approved alternatives are the following:The alternatives are the following approved alternatives:The alternatives are the following:The alternatives are the following:The alternatives are the following:The alternatives are the following:The alternatives are the following:The alternatives are the following:The alternatives are the following:The alternatives are the following:The alternatives are.
# Ground Truth: Identify and replace non-STE words with approved alternatives wash the bike with water.clean the bicycle with water.
# Input: Identify and replace non-STE words with approved alternatives bear down on the surface of the patch to make sure that the parts bond correctly.apply weight on the surface of the patch to make sure that the parts bond correctly.
# Post Process Output: The surface of the.
# Ground Truth: Identify and replace non-STE words with approved alternatives bear down on the surface of the patch to make sure that the parts bond correctly.apply weight on the surface of the patch to make sure that the parts bond correctly.
# ...
# Input: Identify and replace non-STE words with approved alternatives whenever a new revision is available, the status of the last revision changes to "canceled".when a new revision is available, the status of the last revision changes to "canceled".
# Post Process Output: def.
# Ground Truth: Identify and replace non-STE words with approved alternatives whenever a new revision is available, the status of the last revision changes to "canceled".when a new revision is available, the status of the last revision changes to "canceled".
# Input: Identify and replace non-STE words with approved alternatives metal objects may result in magnetic interference.metal objects can cause magnetic interference.
# Post Process Output: if you have metal objects.
# Ground Truth: Identify and replace non-STE words with approved alternatives metal objects may result in magnetic interference.metal objects can cause magnetic interference.
# Input: Identify and replace non-STE words with approved alternatives if the humidity is variable, put a cover on the unit.if the humidity changes frequently, put a cover on the unit.
# Post Process Output: if the humidity is not constant.
# Ground Truth: Identify and replace non-STE words with approved alternatives if the humidity is variable, put a cover on the unit.if the humidity changes frequently, put a cover on the unit.
# Input: Identify and replace non-STE words with approved alternatives the panel's edge distance from the partition must not exceed 0.05 mm.the distance between the edge of the panel and the partition must not be more than 0.05 mm.
# Post Process Output: deflect the light.
# Ground Truth: Identify and replace non-STE words with approved alternatives the panel's edge distance from the partition must not exceed 0.05 mm.the distance between the edge of the panel and the partition must not be more than 0.05 mm.
# Input: Identify and replace non-STE words with approved alternatives coat the battery cables with grease.apply a layer of grease to the battery cables.
# Post Process Output: defrost.
# Ground Truth: Identify and replace non-STE words with approved alternatives coat the battery cables with grease.apply a layer of grease to the battery cables.
# Input: Identify and replace non-STE words with approved alternatives quit the engine test once the flame is out.when the flame extinguishes, stop the engine test.
# Post Process Output: if the flame is.
# Ground Truth: Identify and replace non-STE words with approved alternatives quit the engine test once the flame is out.when the flame extinguishes, stop the engine test.
# Input: Identify and replace non-STE words with approved alternatives devise new troubleshooting procedures.find new troubleshooting procedures.
# Post Process Output: if you are unable to do this repair,.
# Ground Truth: Identify and replace non-STE words with approved alternatives devise new troubleshooting procedures.find new troubleshooting procedures.
# Input: Identify and replace non-STE words with approved alternatives the box is externally mounted.the box is installed externally.
# Post Process Output: if you do the procedure incorrectly, there is a risk of injury.
# Ground Truth: Identify and replace non-STE words with approved alternatives the box is externally mounted.the box is installed externally.
# Input: Identify and replace non-STE words with approved alternatives each electrical system has a code to differentiate it.each electrical system has a code to identify it.
# Post Process Output: if you do not follow this procedure, there are risks of injury.
# Ground Truth: Identify and replace non-STE words with approved alternatives each electrical system has a code to differentiate it.each electrical system has a code to identify it.
# Input: Identify and replace non-STE words with approved alternatives once the unit is on its mounting, lock it.when the unit is on its mounting, lock it.
# Post Process Output: if the unit is on its.
# Ground Truth: Identify and replace non-STE words with approved alternatives once the unit is on its mounting, lock it.when the unit is on its mounting, lock it.
# Input: Identify and replace non-STE words with approved alternatives apply electrical power to either of the solenoids.apply electrical power to one of the two solenoids.
# Post Process Output: if you do this, the lever will move to the "off" position.
# Ground Truth: Identify and replace non-STE words with approved alternatives apply electrical power to either of the solenoids.apply electrical power to one of the two solenoids.
# Input: Identify and replace non-STE words with approved alternatives disconnect the cable from the back side of the instrument.disconnect the cable from the rear side of the instrument.
# Post Process Output: if you do not do this step, there is a risk.
# Ground Truth: Identify and replace non-STE words with approved alternatives disconnect the cable from the back side of the instrument.disconnect the cable from the rear side of the instrument.
# Input: Identify and replace non-STE words with approved alternatives make sure that the fuel tanks are uncontaminated.make sure that there is no contamination in the fuel tanks.
# Post Process Output: if you are not sure that there is contamination in the fuel tanks, replace.
# Ground Truth: Identify and replace non-STE words with approved alternatives make sure that the fuel tanks are uncontaminated.make sure that there is no contamination in the fuel tanks.
# Input: Identify and replace non-STE words with approved alternatives do steps 13 thru 16 at least three times.do steps 13 thru 16 a minimum of three times.
# Post Process Output: if it is possible, do steps 13 thru .
# Ground Truth: Identify and replace non-STE words with approved alternatives do steps 13 thru 16 at least three times.do steps 13 thru 16 a minimum of three times.
# Input: Identify and replace non-STE words with approved alternatives remove the nut and the bolt, and recover the washer.remove the nut and the bolt, and collect the washer.
# Post Process Output: if the washer is removed, install a new one.
# Ground Truth: Identify and replace non-STE words with approved alternatives remove the nut and the bolt, and recover the washer.remove the nut and the bolt, and collect the washer.
# Input: Identify and replace non-STE words with approved alternatives different temperatures will change the cure time.when the temperature increases, the cure time will decrease.
# Post Process Output: if the temperature increases, the cure time will.
# Ground Truth: Identify and replace non-STE words with approved alternatives different temperatures will change the cure time.when the temperature increases, the cure time will decrease.
# Input: Identify and replace non-STE words with approved alternatives the build of the wing allows maximum fuel storage.the wing structure gives maximum fuel capacity.
# Post Process Output: if you have the option, replace.
# Ground Truth: Identify and replace non-STE words with approved alternatives the build of the wing allows maximum fuel storage.the wing structure gives maximum fuel capacity.
# Input: Identify and replace non-STE words with approved alternatives deaerate the tire.deflate the tire.
# Post Process Output: if the pressure is too low, there is a risk.
# Ground Truth: Identify and replace non-STE words with approved alternatives deaerate the tire.deflate the tire.
# Input: Identify and replace non-STE words with approved alternatives open the valve to admit nitrogen into the oleo strut.open the valve to let nitrogen go into the oleo strut.
# Post Process Output: if the fluid level is below the minimum level.
# Ground Truth: Identify and replace non-STE words with approved alternatives open the valve to admit nitrogen into the oleo strut.open the valve to let nitrogen go into the oleo strut.
# Input: Identify and replace non-STE words with approved alternatives wash the brake pads.clean the brake pads.
# Post Process Output: if you do not follow this instruction, damage to.
# Ground Truth: Identify and replace non-STE words with approved alternatives wash the brake pads.clean the brake pads.
# Input: Identify and replace non-STE words with approved alternatives the mounting pads dampen vibration.the mounting pads decrease vibration.
# Post Process Output: if you do not replace the mounting pads, the vibration will increase.
# Ground Truth: Identify and replace non-STE words with approved alternatives the mounting pads dampen vibration.the mounting pads decrease vibration.
# Input: Identify and replace non-STE words with approved alternatives the vanes may be damaged by using incorrect equipment.if you use incorrect equipment, you can cause damage to the vanes.
# Post Process Output: if you use incorrect equipment, damage to.
# Ground Truth: Identify and replace non-STE words with approved alternatives the vanes may be damaged by using incorrect equipment.if you use incorrect equipment, you can cause damage to the vanes.
# Input: Identify and replace non-STE words with approved alternatives make sure that the cables are not loose.make sure that there is tension in the cables.
# Post Process Output: if the cables are.
# Ground Truth: Identify and replace non-STE words with approved alternatives make sure that the cables are not loose.make sure that there is tension in the cables.
# Input: Identify and replace non-STE words with approved alternatives rectify the tension.correct the tension.
# Post Process Output: if the.
# Ground Truth: Identify and replace non-STE words with approved alternatives rectify the tension.correct the tension.
# Input: Identify and replace non-STE words with approved alternatives the actuator is driven to zero.the actuator moves to zero.
# Post Process Output: if you do this step, the actuator will move to zero.
# Ground Truth: Identify and replace non-STE words with approved alternatives the actuator is driven to zero.the actuator moves to zero.
# Input: Identify and replace non-STE words with approved alternatives disassemble the bypass valve and the dump valve together.disassemble the bypass valve and the dump valve at the same time.
# Post Process Output: if you do this repair, make sure that you replace the bypass valve and the dump valve.
# Ground Truth: Identify and replace non-STE words with approved alternatives disassemble the bypass valve and the dump valve together.disassemble the bypass valve and the dump valve at the same time.
# Input: Identify and replace non-STE words with approved alternatives make sure that the fuel tank is tight.make sure that the fuel tank is sealed.
# Post Process Output: if the fuel.
# Ground Truth: Identify and replace non-STE words with approved alternatives make sure that the fuel tank is tight.make sure that the fuel tank is sealed.
# Input: Identify and replace non-STE words with approved alternatives take off the back wheel.remove the rear wheel.
# Post Process Output: if the wheel is not removable, do the.
# Ground Truth: Identify and replace non-STE words with approved alternatives take off the back wheel.remove the rear wheel.
# Input: Identify and replace non-STE words with approved alternatives unscrew the captive bolts.loosen the captive bolts.
# Post Process Output: if the bolts are hard to remove, use a wrench.
# Ground Truth: Identify and replace non-STE words with approved alternatives unscrew the captive bolts.loosen the captive bolts.
# Input: Identify and replace non-STE words with approved alternatives shift the throttle backward.move the throttle aft.
# Post Process Output: if the engine does not start, check the throttle and the mixture.
# Ground Truth: Identify and replace non-STE words with approved alternatives shift the throttle backward.move the throttle aft.
# Input: Identify and replace non-STE words with approved alternatives get access via number 6 break-in panel.get access through the number 6 break-in panel.
# Post Process Output: if you.
# Ground Truth: Identify and replace non-STE words with approved alternatives get access via number 6 break-in panel.get access through the number 6 break-in panel.
# Input: Identify and replace non-STE words with approved alternatives guide the cable through the grommet.put the cable through the grommet.
# Post Process Output: if the cable is damaged, replace it.
# Ground Truth: Identify and replace non-STE words with approved alternatives guide the cable through the grommet.put the cable through the grommet.
# Input: Rewrite the following sentence in a Simplified Technical English format. press down the valve stem core to deaerate.push the valve stem core down to bleed all the air.
# Post Process Output: if you do not do this, there is a risk of engine.
# Ground Truth: Rewrite the following sentence in a Simplified Technical English format. press down the valve stem core to deaerate.push the valve stem core down to bleed all the air.
# Input: Rewrite the following sentence in a Simplified Technical English format. the life of the unit is impaired if the unit is allowed to get dirty.the life of the unit will decrease if you let the unit become dirty.
# Post Process Output: if the unit is dirty, the life of the.
# Ground Truth: Rewrite the following sentence in a Simplified Technical English format. the life of the unit is impaired if the unit is allowed to get dirty.the life of the unit will decrease if you let the unit become dirty.
# Input: Rewrite the following sentence in a Simplified Technical English format. the pressure is elevated.pressure is high.
# Post Process Output: if the pressure is.
# Ground Truth: Rewrite the following sentence in a Simplified Technical English format. the pressure is elevated.pressure is high.
# Input: Rewrite the following sentence in a Simplified Technical English format. hold-on switch trips.the hold-on switch releases.
# Post Process Output: if the hold-on switch.
# Ground Truth: Rewrite the following sentence in a Simplified Technical English format. hold-on switch trips.the hold-on switch releases.
# Input: Rewrite the following sentence in a Simplified Technical English format. do this job in a clean area.do this task in a clean area.
# Post Process Output: if it is possible, do.
# Ground Truth: Rewrite the following sentence in a Simplified Technical English format. do this job in a clean area.do this task in a clean area.
# Input: Rewrite the following sentence in a Simplified Technical English format. if possible, ground run the engine to confirm the indications.if possible, do an engine ground run to make sure that you get the same indications.
# Post Process Output: if possible, do an engine ground run to make sure that you get the same indications.
# Ground Truth: Rewrite the following sentence in a Simplified Technical English format. if possible, ground run the engine to confirm the indications.if possible, do an engine ground run to make sure that you get the same indications.
# Input: Rewrite the following sentence in a Simplified Technical English format. it is common practice to tighten the bolts in this sequence.it is standard procedure to tighten the bolts in this sequence.
# Post Process Output: if it is possible, do the following.
# Ground Truth: Rewrite the following sentence in a Simplified Technical English format. it is common practice to tighten the bolts in this sequence.it is standard procedure to tighten the bolts in this sequence.
# Input: Rewrite the following sentence in a Simplified Technical English format. blot the surface with a towel.dry the surface with a towel.
# Post Process Output: if possible, remove the loose particles from.
# Ground Truth: Rewrite the following sentence in a Simplified Technical English format. blot the surface with a towel.dry the surface with a towel.
# Fold 5 - BLEU: 0, ROUGE-1: 0.30325352977286674, ROUGE-L: 0.21240024554941686
# Avg BLEU: 0.0, Std: 0.0
# Avg ROUGE-1: 0.33327047064668897, Std: 0.0568109333118274
# Avg ROUGE-L: 0.2330530871579696, Std: 0.040532350067872425
# Avg Validation Loss: 1.3153815627098084, Std: 0.36537003015298075
# Avg Training Loss: 1.4457809113820392, Std: 0.7785149612205731
# Training complete.
